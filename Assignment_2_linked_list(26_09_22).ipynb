# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya-Upadhyaya/Ananya-Upadhyaya/blob/main/Assignment_2_linked_list(26_09_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Design a linked list, where every node contains
# firstname,lastname, hobby and phone number**
# **Write functions to perform the following:**

# %% [markdown]
# **1.Add new element to the list**
#
# **2.Search and Rename an element from the list**
#
# **3.Reverse the list**

# %%
class Node:
  
    def __init__(self, info):
        self.info = info 
        self.next = None  
  
  
class LinkedList:
  
    def __init__(self):
        self.head = None
  
    def print(self):
        current = self.head
        while (current):
            print(current.info)
            current = current.next
     
List1 = LinkedList()
  
List1.head = Node("First Name: Stan")
second_Node = Node("Last Name: Paris")
third_Node = Node("Hobby: Painting")
fourth_Node = Node("Phone Number: 964267159")

List1.head.next = second_Node 
second_Node.next = third_Node  
third_Node.next = fourth_Node

List1.print()



# add new element to the list:

class Node:
  
    def __init__(self, info):
        self.info = info 
        self.next = None  
  
  
class LinkedList:
  
    def __init__(self):
        self.head = None
  
    def print(self):
        current = self.head
        while (current):
            print(current.info)
            current = current.next
     



List1 = LinkedList()

List1.head = Node("First Name: Stan")
second_Node = Node("Last Name: Paris")
third_Node = Node("Hobby: Painting")
fourth_Node = Node("Phone Number: 964267159")
fifth_Node = Node("Location: Goa")

List1.head.next = second_Node 
second_Node.next = third_Node  
third_Node.next = fourth_Node
fourth_Node.next = fifth_Node

List1.print()


# Search and Rename an element from the list

class Node:
 
    def __init__(self, info):
        self.info = info  
        self.next = None  
 
 
class LinkedList:
    def __init__(self):
        self.head = None  
 
   
    def insert(self, new_info):
        new_node = Node(new_info)
        new_node.next = self.head
        self.head = new_node # head to point to new Node
 
   
    def search(self, x):
 
# Initialize current to head
        curr = self.head

        while curr != None:
            if curr.info == x:
                return True  
            
            curr.info = "Suzain"
            curr = curr.next
        return False 

List1 = LinkedList()
  
List1.head = Node("First Name: Stan")
second_Node = Node("Last Name: Paris")
third_Node = Node("Hobby: Painting")
fourth_Node = Node("Phone Number: 964267159")

  
List1.head.next = second_Node 
second_Node.next = third_Node  
third_Node.next = fourth_Node


#search("First Name: Stan")

if List1.search("First Name: Stan"):
        print("First Name: Suzain")
else:
  print("Does not match")



# Reverse the list

class Node:

    def __init__(self, info):
        self.info = info
        self.next = None
 
 
class LinkedList:
 
# initialize head
    def __init__(self):
        self.head = None
 
# reverse the linked list
    def reverse(self):
        prev = None
        current = self.head
        while(current != None):
            next = current.next
            current.next = previous
            previous = current
            current = next
        self.head = previous
 
 # insert a new node at the beginning
    def insert(self, new_info):
        new_node = Node(new_info)
        new_node.next = self.head
        self.head = new_node
 
    def print(self):
        temp = self.head
        while(temp):
            print(temp.info, end=" ")
            temp = temp.next
 
 
List1 = LinkedList()
List1.insert("Stan")
List1.insert("Paris")
List1.insert("Painting")
List1.insert("964267159")
 
print("Reversed Linked List")
List1.print()
List1.reverse()
print("\nGiven Linked List") 
List1.print()
# Out:
# First Name: Stan
# Last Name: Paris
# Hobby: Painting
# Phone Number: 964267159
# First Name: Stan
# Last Name: Paris
# Hobby: Painting
# Phone Number: 964267159
# Location: Goa
# First Name: Suzain
# Reversed Linked List
# 964267159 Painting Paris Stan
# Given Linked List
# Stan Paris Painting 964267159
